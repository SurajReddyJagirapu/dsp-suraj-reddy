# %%
import numpy as np

from IPython.display import display

my_array = np.random.randint(0, 100, size=(10, 3))

display(my_array)
# Out:
# array([[75, 40, 10],
#        [91, 44, 18],
#        [35, 59, 88],
#        [ 3, 81, 59],
#        [19, 40, 45],
#        [ 5, 11, 61],
#        [24, 34, 58],
#        [ 8, 13, 39],
#        [43, 15, 35],
#        [59, 52, 40]])
